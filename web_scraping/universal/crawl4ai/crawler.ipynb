# %%
# !pip3 install crawl4ai

# %%
import os
import sys
os.environ['PYTHONPATH'] = os.path.expanduser('~/mhbai')
sys.path.append(os.path.expanduser('~/mhbai'))

# %%
from crawl4ai import AsyncWebCrawler
from web_scraping.universal.crawl4ai.prompt import instructions

start_url = "https://www.uni-wuerzburg.de/"


async with AsyncWebCrawler() as crawler:
    results = await crawler.arun(
        url=start_url,
        instruction=instructions,
        max_depth=4,
    )
# Out:
# [INIT].... → Crawl4AI 0.8.6
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       2 from web_scraping.universal.crawl4ai.prompt import instructions
#       3
#       4 async with AsyncWebCrawler() as crawler:
#       5     results = await crawler.arun(
# ----> 6         url=start_url,
#       7         instruction=instruction,
#       8         max_depth=4,
#       9     )
#
# NameError: name 'start_url' is not defined
